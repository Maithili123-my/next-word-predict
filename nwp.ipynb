# %%
#Beginning of the model importing the libraries required
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

# %%
# text data
with open("input.txt", "r", encoding="utf-8") as f:
    text = f.read().lower()

# %%
# Tokenization
tokenizer = Tokenizer()
tokenizer.fit_on_texts([text])

total_words = len(tokenizer.word_index) + 1

# %%
# create input sequences
input_sequences = []
for line in text.split("\n"):
    tokens = tokenizer.texts_to_sequences([line])[0]
    for i in range(1, len(tokens)):
        seq = tokens[:i+1]
        input_sequences.append(seq)

# %%
# pad sequences
max_seq_len = max(len(seq) for seq in input_sequences)
input_sequences = pad_sequences(input_sequences, maxlen=max_seq_len, padding='pre')
input_sequences = np.array(input_sequences)

X = input_sequences[:, :-1]
y = input_sequences[:, -1]

# %%
y = np.eye(total_words)[y] #encodeing output

# %%
#Building the Model
from tensorflow.keras.layers import Input

model = Sequential()
model.add(Input(shape=(max_seq_len -1,)))
model.add(Embedding(total_words,50))
model.add(LSTM(100))
model.add(Dense(total_words, activation='softmax'))

model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)                │ (None, 9, 50)               │           3,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ (None, 100)                 │          60,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 68)                  │           6,868 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 70,668 (276.05 KB)
#  Trainable params: 70,668 (276.05 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Training the model
model.fit(X, y, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 3/3 - 16s - 5s/step - accuracy: 0.0435 - loss: 4.2183
# Epoch 2/100
# 3/3 - 1s - 301ms/step - accuracy: 0.1196 - loss: 4.2016
# Epoch 3/100
# 3/3 - 0s - 99ms/step - accuracy: 0.1196 - loss: 4.1839
# Epoch 4/100
# 3/3 - 0s - 127ms/step - accuracy: 0.1522 - loss: 4.1536
# Epoch 5/100
# 3/3 - 0s - 116ms/step - accuracy: 0.1630 - loss: 4.1085
# Epoch 6/100
# 3/3 - 0s - 104ms/step - accuracy: 0.1848 - loss: 4.0108
# Epoch 7/100
# 3/3 - 0s - 107ms/step - accuracy: 0.1304 - loss: 3.8777
# Epoch 8/100
# 3/3 - 0s - 113ms/step - accuracy: 0.1522 - loss: 3.8480
# Epoch 9/100
# 3/3 - 0s - 135ms/step - accuracy: 0.1087 - loss: 3.8662
# Epoch 10/100
# 3/3 - 1s - 210ms/step - accuracy: 0.1087 - loss: 3.8115
# Epoch 11/100
# 3/3 - 0s - 118ms/step - accuracy: 0.1087 - loss: 3.7773
# Epoch 12/100
# 3/3 - 0s - 114ms/step - accuracy: 0.1087 - loss: 3.7754
# Epoch 13/100
# 3/3 - 0s - 101ms/step - accuracy: 0.1087 - loss: 3.7607
# Epoch 14/100
# 3/3 - 0s - 118ms/step - accuracy: 0.1087 - loss: 3.7274
# Epoch 15/100
# 3/3 - 0s - 115ms/step - accuracy: 0.1630 - loss: 3.6999
# Epoch 16/100
# 3/3 - 0s - 107ms/step - accuracy: 0.1739 - loss: 3.6791
# Epoch 17/100
# 3/3 - 0s - 130ms/step - accuracy: 0.1739 - loss: 3.6576
# Epoch 18/100
# 3/3 - 0s - 119ms/step - accuracy: 0.1739 - loss: 3.6234
# Epoch 19/100
# 3/3 - 0s - 111ms/step - accuracy: 0.1739 - loss: 3.5920
# Epoch 20/100
# 3/3 - 0s - 109ms/step - accuracy: 0.1848 - loss: 3.5524
# Epoch 21/100
# 3/3 - 0s - 130ms/step - accuracy: 0.1957 - loss: 3.5161
# Epoch 22/100
# 3/3 - 0s - 115ms/step - accuracy: 0.2500 - loss: 3.4843
# Epoch 23/100
# 3/3 - 0s - 112ms/step - accuracy: 0.2500 - loss: 3.4388
# Epoch 24/100
# 3/3 - 0s - 125ms/step - accuracy: 0.2717 - loss: 3.3943
# Epoch 25/100
# 3/3 - 0s - 115ms/step - accuracy: 0.2283 - loss: 3.3593
# Epoch 26/100
# 3/3 - 0s - 130ms/step - accuracy: 0.2717 - loss: 3.3160
# Epoch 27/100
# 3/3 - 0s - 87ms/step - accuracy: 0.2717 - loss: 3.2706
# Epoch 28/100
# 3/3 - 0s - 120ms/step - accuracy: 0.2717 - loss: 3.2296
# Epoch 29/100
# 3/3 - 0s - 111ms/step - accuracy: 0.2717 - loss: 3.1852
# Epoch 30/100
# 3/3 - 0s - 104ms/step - accuracy: 0.2609 - loss: 3.1485
# Epoch 31/100
# 3/3 - 0s - 126ms/step - accuracy: 0.2717 - loss: 3.1075
# Epoch 32/100
# 3/3 - 0s - 111ms/step - accuracy: 0.2826 - loss: 3.0600
# Epoch 33/100
# 3/3 - 0s - 108ms/step - accuracy: 0.2717 - loss: 3.0191
# Epoch 34/100
# 3/3 - 1s - 251ms/step - accuracy: 0.2717 - loss: 2.9726
# Epoch 35/100
# 3/3 - 0s - 110ms/step - accuracy: 0.2826 - loss: 2.9232
# Epoch 36/100
# 3/3 - 0s - 120ms/step - accuracy: 0.3152 - loss: 2.8891
# Epoch 37/100
# 3/3 - 1s - 219ms/step - accuracy: 0.3152 - loss: 2.8380
# Epoch 38/100
# 3/3 - 0s - 119ms/step - accuracy: 0.3152 - loss: 2.7977
# Epoch 39/100
# 3/3 - 0s - 130ms/step - accuracy: 0.3152 - loss: 2.7607
# Epoch 40/100
# 3/3 - 0s - 89ms/step - accuracy: 0.3370 - loss: 2.7105
# Epoch 41/100
# 3/3 - 0s - 113ms/step - accuracy: 0.3370 - loss: 2.6675
# Epoch 42/100
# 3/3 - 0s - 128ms/step - accuracy: 0.3587 - loss: 2.6271
# Epoch 43/100
# 3/3 - 0s - 91ms/step - accuracy: 0.3587 - loss: 2.5793
# Epoch 44/100
# 3/3 - 0s - 125ms/step - accuracy: 0.3587 - loss: 2.5375
# Epoch 45/100
# 3/3 - 0s - 97ms/step - accuracy: 0.3370 - loss: 2.4930
# Epoch 46/100
# 3/3 - 0s - 115ms/step - accuracy: 0.3696 - loss: 2.4573
# Epoch 47/100
# 3/3 - 0s - 111ms/step - accuracy: 0.3804 - loss: 2.4191
# Epoch 48/100
# 3/3 - 0s - 112ms/step - accuracy: 0.4022 - loss: 2.3735
# Epoch 49/100
# 3/3 - 0s - 124ms/step - accuracy: 0.3804 - loss: 2.3339
# Epoch 50/100
# 3/3 - 0s - 127ms/step - accuracy: 0.3913 - loss: 2.2898
# Epoch 51/100
# 3/3 - 0s - 106ms/step - accuracy: 0.4130 - loss: 2.2588
# Epoch 52/100
# 3/3 - 0s - 116ms/step - accuracy: 0.4239 - loss: 2.2133
# Epoch 53/100
# 3/3 - 0s - 96ms/step - accuracy: 0.4457 - loss: 2.1775
# Epoch 54/100
# 3/3 - 0s - 131ms/step - accuracy: 0.4348 - loss: 2.1353
# Epoch 55/100
# 3/3 - 0s - 111ms/step - accuracy: 0.5000 - loss: 2.1034
# Epoch 56/100
# 3/3 - 0s - 118ms/step - accuracy: 0.5000 - loss: 2.0636
# Epoch 57/100
# 3/3 - 0s - 107ms/step - accuracy: 0.5217 - loss: 2.0306
# Epoch 58/100
# 3/3 - 0s - 114ms/step - accuracy: 0.5217 - loss: 1.9926
# Epoch 59/100
# 3/3 - 0s - 116ms/step - accuracy: 0.5109 - loss: 1.9555
# Epoch 60/100
# 3/3 - 0s - 118ms/step - accuracy: 0.5326 - loss: 1.9258
# Epoch 61/100
# 3/3 - 0s - 127ms/step - accuracy: 0.5435 - loss: 1.8866
# Epoch 62/100
# 3/3 - 0s - 113ms/step - accuracy: 0.5761 - loss: 1.8506
# Epoch 63/100
# 3/3 - 0s - 135ms/step - accuracy: 0.5870 - loss: 1.8172
# Epoch 64/100
# 3/3 - 0s - 127ms/step - accuracy: 0.5652 - loss: 1.7881
# Epoch 65/100
# 3/3 - 0s - 136ms/step - accuracy: 0.6087 - loss: 1.7562
# Epoch 66/100
# 3/3 - 0s - 126ms/step - accuracy: 0.6196 - loss: 1.7253
# Epoch 67/100
# 3/3 - 0s - 113ms/step - accuracy: 0.6522 - loss: 1.6933
# Epoch 68/100
# 3/3 - 0s - 110ms/step - accuracy: 0.6630 - loss: 1.6608
# Epoch 69/100
# 3/3 - 0s - 123ms/step - accuracy: 0.6630 - loss: 1.6315
# Epoch 70/100
# 3/3 - 0s - 125ms/step - accuracy: 0.6739 - loss: 1.6010
# Epoch 71/100
# 3/3 - 0s - 129ms/step - accuracy: 0.6848 - loss: 1.5723
# Epoch 72/100
# 3/3 - 0s - 113ms/step - accuracy: 0.6848 - loss: 1.5479
# Epoch 73/100
# 3/3 - 0s - 108ms/step - accuracy: 0.6739 - loss: 1.5173
# Epoch 74/100
# 3/3 - 0s - 130ms/step - accuracy: 0.6848 - loss: 1.5002
# Epoch 75/100
# 3/3 - 0s - 107ms/step - accuracy: 0.6848 - loss: 1.4663
# Epoch 76/100
# 3/3 - 0s - 121ms/step - accuracy: 0.7065 - loss: 1.4390
# Epoch 77/100
# 3/3 - 0s - 125ms/step - accuracy: 0.7174 - loss: 1.4145
# Epoch 78/100
# 3/3 - 1s - 246ms/step - accuracy: 0.7391 - loss: 1.3933
# Epoch 79/100
# 3/3 - 0s - 112ms/step - accuracy: 0.7391 - loss: 1.3697
# Epoch 80/100
# 3/3 - 0s - 121ms/step - accuracy: 0.7609 - loss: 1.3456
# Epoch 81/100
# 3/3 - 0s - 111ms/step - accuracy: 0.7609 - loss: 1.3249
# Epoch 82/100
# 3/3 - 0s - 116ms/step - accuracy: 0.7500 - loss: 1.3003
# Epoch 83/100
# 3/3 - 0s - 121ms/step - accuracy: 0.7500 - loss: 1.2794
# Epoch 84/100
# 3/3 - 0s - 132ms/step - accuracy: 0.7826 - loss: 1.2555
# Epoch 85/100
# 3/3 - 0s - 114ms/step - accuracy: 0.7935 - loss: 1.2364
# Epoch 86/100
# 3/3 - 0s - 126ms/step - accuracy: 0.8043 - loss: 1.2156
# Epoch 87/100
# 3/3 - 0s - 100ms/step - accuracy: 0.8043 - loss: 1.1930
# Epoch 88/100
# 3/3 - 0s - 133ms/step - accuracy: 0.8152 - loss: 1.1771
# Epoch 89/100
# 3/3 - 0s - 108ms/step - accuracy: 0.8152 - loss: 1.1562
# Epoch 90/100
# 3/3 - 0s - 118ms/step - accuracy: 0.8370 - loss: 1.1370
# Epoch 91/100
# 3/3 - 0s - 129ms/step - accuracy: 0.8370 - loss: 1.1175
# Epoch 92/100
# 3/3 - 0s - 121ms/step - accuracy: 0.8370 - loss: 1.1027
# Epoch 93/100
# 3/3 - 0s - 104ms/step - accuracy: 0.8370 - loss: 1.0797
# Epoch 94/100
# 3/3 - 0s - 119ms/step - accuracy: 0.8370 - loss: 1.0630
# Epoch 95/100
# 3/3 - 0s - 124ms/step - accuracy: 0.8478 - loss: 1.0462
# Epoch 96/100
# 3/3 - 0s - 133ms/step - accuracy: 0.8370 - loss: 1.0320
# Epoch 97/100
# 3/3 - 0s - 80ms/step - accuracy: 0.8478 - loss: 1.0152
# Epoch 98/100
# 3/3 - 0s - 108ms/step - accuracy: 0.8478 - loss: 0.9966
# Epoch 99/100
# 3/3 - 1s - 205ms/step - accuracy: 0.8478 - loss: 0.9842
# Epoch 100/100
# 3/3 - 1s - 214ms/step - accuracy: 0.8478 - loss: 0.9644

# %%
def predict_next_word(model, tokenizer, seed_text, max_seq_len):
    # Convert to sequence of ints
    token_list = tokenizer.texts_to_sequences([seed_text])[0]
    token_list = pad_sequences([token_list], maxlen=max_seq_len - 1, padding='pre')

    # Get prediction probabilities
    predicted_probs = model.predict(token_list, verbose=0)[0]

    # Find the index of the highest probability
    predicted_index = np.argmax(predicted_probs)

    # Map index back to word
    if predicted_index in tokenizer.index_word:
        return tokenizer.index_word[predicted_index]
    else:
        # If not found, return empty or placeholder
        return "<unk>"

# %%
next_word = predict_next_word(model, tokenizer, "The man with", max_seq_len)
print("Predicted next word:", next_word)
# Out:
# Predicted next word: the
